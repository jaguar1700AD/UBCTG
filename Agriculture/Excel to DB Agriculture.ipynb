# %%
import pandas as pd 
from sqlalchemy import create_engine
import mysql.connector

# %%
file_name = "Agricultural_Commodities_Prices_data"

host_val = "ubctg.con7266gcvin.us-east-2.rds.amazonaws.com"
user_val = "admin"
password_val = "ubctgquant"
database_val = "ubctg"

# %%
# Connect to MySQL database
connection = mysql.connector.connect(
    host=host_val,
    user=user_val,
    password=password_val,
    database=database_val
)

# %%
hostname= "localhost"
database= "new_db"
username= "username"
password= "password"

engine = create_engine("mysql://{user}:{pw}@{host}/{db}".format(host=host_val, db=database_val, user=user_val, pw=password_val))

# %%
my_file = open("Names.txt", "r") 
names = my_file.read().split("\n") 
my_file.close()

names
# Out:
# ['generic 1st wheat (CBT)',
#  'generic 1st maize (EOP)',
#  'generic 1st barley (NDX)',
#  'generic 1st rice, rough (CBT)',
#  'generic 1st canola (WCE)',
#  'generic 1st oats (CBT)',
#  'generic 1st soybean (CBT)',
#  'generic 1st crude palm oil (MDE)',
#  'generic 1st rapeseed oil (EOP)',
#  'generic 1st sunflower oil, refined (MCI)',
#  'generic 1st cotton, No. 2 (NYB)',
#  'generic 1st cocoa (NYB)',
#  "generic 1st coffee, 'C' (NYB)",
#  'generic 1st rubber, TSR20 (SGX)',
#  'generic 1st sugar, #11 World (NYB)',
#  'generic 1st urea (CME)',
#  'generic 1st SGX Argus Ammonia CFR East Asia Futures (SGX)',
#  'generic 1st milk (CME)',
#  'generic 1st eggs, Chicken (CCO)',
#  'generic 1st lean hogs (CME)',
#  'generic 1st beef future contract (SAF)',
#  'generic 1st norwegian Salmon Month (FPL)',
#  'generic 1st wood pulp, hardwood pulp (CME)',
#  'generic 1st turmeric (NDX)']

# %%
df = pd.read_excel(file_name + ".xlsx")
df
# Out:
#                       0           1          2           3          4   \
# 0                    NaN  W 1 Comdty        NaN  EP1 Comdty        NaN
# 1                  Dates     PX_LAST  PX_VOLUME     PX_LAST  PX_VOLUME
# 2    1959-08-31 00:00:00      190.75        NaN         NaN        NaN
# 3    1959-09-30 00:00:00       196.5        NaN         NaN        NaN
# 4    1959-10-30 00:00:00     200.375        NaN         NaN        NaN
# ..                   ...         ...        ...         ...        ...
# 775  2024-01-31 00:00:00      595.25    1148200       182.5      28940
# 776  2024-02-29 00:00:00       577.5    1069598         178      28305
# 777  2024-03-29 00:00:00      560.25     522542      193.25      34063
# 778  2024-04-30 00:00:00         585    1101393         201      31085
# 779  2024-05-31 00:00:00       678.5     892110         224      22621
#
#              5          6           7          8           9   ...  \
# 0    FU1 Comdty        NaN  RR1 Comdty        NaN  RS1 Comdty  ...
# 1       PX_LAST  PX_VOLUME     PX_LAST  PX_VOLUME     PX_LAST  ...
# 2           NaN        NaN         NaN        NaN         NaN  ...
# 3           NaN        NaN         NaN        NaN         NaN  ...
# 4           NaN        NaN         NaN        NaN         NaN  ...
# ..          ...        ...         ...        ...         ...  ...
# 775        2000         40      17.865       8758       610.4  ...
# 776        2033         40       17.87      18174       577.3  ...
# 777        1965        230       16.36       8762       626.4  ...
# 778      2016.5         30       18.89      17630       603.8  ...
# 779        2166         30       17.67       5997         661  ...
#
#              39         40           41         42           43         44  \
# 0    LH1 Comdty        NaN  BFC1 Comdty        NaN  CSA1 Comdty        NaN
# 1       PX_LAST  PX_VOLUME      PX_LAST  PX_VOLUME      PX_LAST  PX_VOLUME
# 2           NaN        NaN          NaN        NaN          NaN        NaN
# 3           NaN        NaN          NaN        NaN          NaN        NaN
# 4           NaN        NaN          NaN        NaN          NaN        NaN
# ..          ...        ...          ...        ...          ...        ...
# 775       76.35     462003         45.7          4          107         10
# 776      86.625     300415         45.7          4        114.5         10
# 777      86.625     404533         45.7          4        113.2         10
# 778       94.15      73164         45.7          4        130.6         10
# 779       94.35     168184         45.7          4          122         10
#
#               45         46          47         48
# 0    HWP1 Comdty        NaN  Q61 Comdty        NaN
# 1        PX_LAST  PX_VOLUME     PX_LAST  PX_VOLUME
# 2            NaN        NaN         NaN        NaN
# 3            NaN        NaN         NaN        NaN
# 4            NaN        NaN         NaN        NaN
# ..           ...        ...         ...        ...
# 775        687.2        100       14096      63085
# 776        687.2        100       17162      57425
# 777        687.2        100       17138      78535
# 778        687.2        100       19212      62505
# 779        687.2        100       17606      91890
#
# [780 rows x 49 columns]

# %%
col_names = ["Date"]
for x in names:
    col_names.append(x + ": Price")
    col_names.append(x + ": Vol")
col_names
# Out:
# ['Date',
#  'generic 1st wheat (CBT): Price',
#  'generic 1st wheat (CBT): Vol',
#  'generic 1st maize (EOP): Price',
#  'generic 1st maize (EOP): Vol',
#  'generic 1st barley (NDX): Price',
#  'generic 1st barley (NDX): Vol',
#  'generic 1st rice, rough (CBT): Price',
#  'generic 1st rice, rough (CBT): Vol',
#  'generic 1st canola (WCE): Price',
#  'generic 1st canola (WCE): Vol',
#  'generic 1st oats (CBT): Price',
#  'generic 1st oats (CBT): Vol',
#  'generic 1st soybean (CBT): Price',
#  'generic 1st soybean (CBT): Vol',
#  'generic 1st crude palm oil (MDE): Price',
#  'generic 1st crude palm oil (MDE): Vol',
#  'generic 1st rapeseed oil (EOP): Price',
#  'generic 1st rapeseed oil (EOP): Vol',
#  'generic 1st sunflower oil, refined (MCI): Price',
#  'generic 1st sunflower oil, refined (MCI): Vol',
#  'generic 1st cotton, No. 2 (NYB): Price',
#  'generic 1st cotton, No. 2 (NYB): Vol',
#  'generic 1st cocoa (NYB): Price',
#  'generic 1st cocoa (NYB): Vol',
#  "generic 1st coffee, 'C' (NYB): Price",
#  "generic 1st coffee, 'C' (NYB): Vol",
#  'generic 1st rubber, TSR20 (SGX): Price',
#  'generic 1st rubber, TSR20 (SGX): Vol',
#  'generic 1st sugar, #11 World (NYB): Price',
#  'generic 1st sugar, #11 World (NYB): Vol',
#  'generic 1st urea (CME): Price',
#  'generic 1st urea (CME): Vol',
#  'generic 1st SGX Argus Ammonia CFR East Asia Futures (SGX): Price',
#  'generic 1st SGX Argus Ammonia CFR East Asia Futures (SGX): Vol',
#  'generic 1st milk (CME): Price',
#  'generic 1st milk (CME): Vol',
#  'generic 1st eggs, Chicken (CCO): Price',
#  'generic 1st eggs, Chicken (CCO): Vol',
#  'generic 1st lean hogs (CME): Price',
#  'generic 1st lean hogs (CME): Vol',
#  'generic 1st beef future contract (SAF): Price',
#  'generic 1st beef future contract (SAF): Vol',
#  'generic 1st norwegian Salmon Month (FPL): Price',
#  'generic 1st norwegian Salmon Month (FPL): Vol',
#  'generic 1st wood pulp, hardwood pulp (CME): Price',
#  'generic 1st wood pulp, hardwood pulp (CME): Vol',
#  'generic 1st turmeric (NDX): Price',
#  'generic 1st turmeric (NDX): Vol']

# %%
df = df.set_axis(col_names, axis = 1)
df
# Out:
#                     Date generic 1st wheat (CBT): Price  \
# 0                    NaN                     W 1 Comdty
# 1                  Dates                        PX_LAST
# 2    1959-08-31 00:00:00                         190.75
# 3    1959-09-30 00:00:00                          196.5
# 4    1959-10-30 00:00:00                        200.375
# ..                   ...                            ...
# 775  2024-01-31 00:00:00                         595.25
# 776  2024-02-29 00:00:00                          577.5
# 777  2024-03-29 00:00:00                         560.25
# 778  2024-04-30 00:00:00                            585
# 779  2024-05-31 00:00:00                          678.5
#
#     generic 1st wheat (CBT): Vol generic 1st maize (EOP): Price  \
# 0                            NaN                     EP1 Comdty
# 1                      PX_VOLUME                        PX_LAST
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# ..                           ...                            ...
# 775                      1148200                          182.5
# 776                      1069598                            178
# 777                       522542                         193.25
# 778                      1101393                            201
# 779                       892110                            224
#
#     generic 1st maize (EOP): Vol generic 1st barley (NDX): Price  \
# 0                            NaN                      FU1 Comdty
# 1                      PX_VOLUME                         PX_LAST
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# ..                           ...                             ...
# 775                        28940                            2000
# 776                        28305                            2033
# 777                        34063                            1965
# 778                        31085                          2016.5
# 779                        22621                            2166
#
#     generic 1st barley (NDX): Vol generic 1st rice, rough (CBT): Price  \
# 0                             NaN                           RR1 Comdty
# 1                       PX_VOLUME                              PX_LAST
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
# ..                            ...                                  ...
# 775                            40                               17.865
# 776                            40                                17.87
# 777                           230                                16.36
# 778                            30                                18.89
# 779                            30                                17.67
#
#     generic 1st rice, rough (CBT): Vol generic 1st canola (WCE): Price  ...  \
# 0                                  NaN                      RS1 Comdty  ...
# 1                            PX_VOLUME                         PX_LAST  ...
# 2                                  NaN                             NaN  ...
# 3                                  NaN                             NaN  ...
# 4                                  NaN                             NaN  ...
# ..                                 ...                             ...  ...
# 775                               8758                           610.4  ...
# 776                              18174                           577.3  ...
# 777                               8762                           626.4  ...
# 778                              17630                           603.8  ...
# 779                               5997                             661  ...
#
#     generic 1st lean hogs (CME): Price generic 1st lean hogs (CME): Vol  \
# 0                           LH1 Comdty                              NaN
# 1                              PX_LAST                        PX_VOLUME
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ..                                 ...                              ...
# 775                              76.35                           462003
# 776                             86.625                           300415
# 777                             86.625                           404533
# 778                              94.15                            73164
# 779                              94.35                           168184
#
#     generic 1st beef future contract (SAF): Price  \
# 0                                     BFC1 Comdty
# 1                                         PX_LAST
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 775                                          45.7
# 776                                          45.7
# 777                                          45.7
# 778                                          45.7
# 779                                          45.7
#
#     generic 1st beef future contract (SAF): Vol  \
# 0                                           NaN
# 1                                     PX_VOLUME
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 775                                           4
# 776                                           4
# 777                                           4
# 778                                           4
# 779                                           4
#
#     generic 1st norwegian Salmon Month (FPL): Price  \
# 0                                       CSA1 Comdty
# 1                                           PX_LAST
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 775                                             107
# 776                                           114.5
# 777                                           113.2
# 778                                           130.6
# 779                                             122
#
#     generic 1st norwegian Salmon Month (FPL): Vol  \
# 0                                             NaN
# 1                                       PX_VOLUME
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 775                                            10
# 776                                            10
# 777                                            10
# 778                                            10
# 779                                            10
#
#     generic 1st wood pulp, hardwood pulp (CME): Price  \
# 0                                         HWP1 Comdty
# 1                                             PX_LAST
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 775                                             687.2
# 776                                             687.2
# 777                                             687.2
# 778                                             687.2
# 779                                             687.2
#
#     generic 1st wood pulp, hardwood pulp (CME): Vol  \
# 0                                               NaN
# 1                                         PX_VOLUME
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 775                                             100
# 776                                             100
# 777                                             100
# 778                                             100
# 779                                             100
#
#     generic 1st turmeric (NDX): Price generic 1st turmeric (NDX): Vol
# 0                          Q61 Comdty                             NaN
# 1                             PX_LAST                       PX_VOLUME
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ..                                ...                             ...
# 775                             14096                           63085
# 776                             17162                           57425
# 777                             17138                           78535
# 778                             19212                           62505
# 779                             17606                           91890
#
# [780 rows x 49 columns]

# %%
df.to_sql(file_name, engine, if_exists='replace')
# Out:
# 780

# %%
df = pd.read_sql('SELECT * from ' + file_name, con=engine)
df
# Out:
#      index                 Date generic 1st wheat (CBT): Price  \
# 0        0                 None                     W 1 Comdty
# 1        1                Dates                        PX_LAST
# 2        2  1959-08-31 00:00:00                         190.75
# 3        3  1959-09-30 00:00:00                          196.5
# 4        4  1959-10-30 00:00:00                        200.375
# ..     ...                  ...                            ...
# 775    775  2024-01-31 00:00:00                         595.25
# 776    776  2024-02-29 00:00:00                          577.5
# 777    777  2024-03-29 00:00:00                         560.25
# 778    778  2024-04-30 00:00:00                            585
# 779    779  2024-05-31 00:00:00                          678.5
#
#     generic 1st wheat (CBT): Vol generic 1st maize (EOP): Price  \
# 0                           None                     EP1 Comdty
# 1                      PX_VOLUME                        PX_LAST
# 2                           None                           None
# 3                           None                           None
# 4                           None                           None
# ..                           ...                            ...
# 775                      1148200                          182.5
# 776                      1069598                            178
# 777                       522542                         193.25
# 778                      1101393                            201
# 779                       892110                            224
#
#     generic 1st maize (EOP): Vol generic 1st barley (NDX): Price  \
# 0                           None                      FU1 Comdty
# 1                      PX_VOLUME                         PX_LAST
# 2                           None                            None
# 3                           None                            None
# 4                           None                            None
# ..                           ...                             ...
# 775                        28940                            2000
# 776                        28305                            2033
# 777                        34063                            1965
# 778                        31085                          2016.5
# 779                        22621                            2166
#
#     generic 1st barley (NDX): Vol generic 1st rice, rough (CBT): Price  \
# 0                            None                           RR1 Comdty
# 1                       PX_VOLUME                              PX_LAST
# 2                            None                                 None
# 3                            None                                 None
# 4                            None                                 None
# ..                            ...                                  ...
# 775                            40                               17.865
# 776                            40                                17.87
# 777                           230                                16.36
# 778                            30                                18.89
# 779                            30                                17.67
#
#     generic 1st rice, rough (CBT): Vol  ...  \
# 0                                 None  ...
# 1                            PX_VOLUME  ...
# 2                                 None  ...
# 3                                 None  ...
# 4                                 None  ...
# ..                                 ...  ...
# 775                               8758  ...
# 776                              18174  ...
# 777                               8762  ...
# 778                              17630  ...
# 779                               5997  ...
#
#     generic 1st lean hogs (CME): Price generic 1st lean hogs (CME): Vol  \
# 0                           LH1 Comdty                             None
# 1                              PX_LAST                        PX_VOLUME
# 2                                 None                             None
# 3                                 None                             None
# 4                                 None                             None
# ..                                 ...                              ...
# 775                              76.35                           462003
# 776                             86.625                           300415
# 777                             86.625                           404533
# 778                              94.15                            73164
# 779                              94.35                           168184
#
#     generic 1st beef future contract (SAF): Price  \
# 0                                     BFC1 Comdty
# 1                                         PX_LAST
# 2                                            None
# 3                                            None
# 4                                            None
# ..                                            ...
# 775                                          45.7
# 776                                          45.7
# 777                                          45.7
# 778                                          45.7
# 779                                          45.7
#
#     generic 1st beef future contract (SAF): Vol  \
# 0                                          None
# 1                                     PX_VOLUME
# 2                                          None
# 3                                          None
# 4                                          None
# ..                                          ...
# 775                                           4
# 776                                           4
# 777                                           4
# 778                                           4
# 779                                           4
#
#     generic 1st norwegian Salmon Month (FPL): Price  \
# 0                                       CSA1 Comdty
# 1                                           PX_LAST
# 2                                              None
# 3                                              None
# 4                                              None
# ..                                              ...
# 775                                             107
# 776                                           114.5
# 777                                           113.2
# 778                                           130.6
# 779                                             122
#
#     generic 1st norwegian Salmon Month (FPL): Vol  \
# 0                                            None
# 1                                       PX_VOLUME
# 2                                            None
# 3                                            None
# 4                                            None
# ..                                            ...
# 775                                            10
# 776                                            10
# 777                                            10
# 778                                            10
# 779                                            10
#
#     generic 1st wood pulp, hardwood pulp (CME): Price  \
# 0                                         HWP1 Comdty
# 1                                             PX_LAST
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 775                                             687.2
# 776                                             687.2
# 777                                             687.2
# 778                                             687.2
# 779                                             687.2
#
#     generic 1st wood pulp, hardwood pulp (CME): Vol  \
# 0                                              None
# 1                                         PX_VOLUME
# 2                                              None
# 3                                              None
# 4                                              None
# ..                                              ...
# 775                                             100
# 776                                             100
# 777                                             100
# 778                                             100
# 779                                             100
#
#     generic 1st turmeric (NDX): Price generic 1st turmeric (NDX): Vol
# 0                          Q61 Comdty                            None
# 1                             PX_LAST                       PX_VOLUME
# 2                                None                            None
# 3                                None                            None
# 4                                None                            None
# ..                                ...                             ...
# 775                             14096                           63085
# 776                             17162                           57425
# 777                             17138                           78535
# 778                             19212                           62505
# 779                             17606                           91890
#
# [780 rows x 50 columns]

# %%
connection.close()
