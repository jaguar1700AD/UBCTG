# %%
import pandas as pd 
from sqlalchemy import create_engine
import mysql.connector

# %%
file_name = "Energy_Prices_data"

host_val = "ubctg.con7266gcvin.us-east-2.rds.amazonaws.com"
user_val = "admin"
password_val = "ubctgquant"
database_val = "ubctg"

# %%
# Connect to MySQL database
connection = mysql.connector.connect(
    host=host_val,
    user=user_val,
    password=password_val,
    database=database_val
)

# %%
hostname= "localhost"
database= "new_db"
username= "username"
password= "password"

engine = create_engine("mysql://{user}:{pw}@{host}/{db}".format(host=host_val, db=database_val, user=user_val, pw=password_val))

# %%
my_file = open("Names.txt", "r") 
names = my_file.read().split("\n") 
my_file.close()

names
# Out:
# ['Generic 1st Crude Oil, WTI (NYM)',
#  'Generic 1st Natural Gas (NYM)',
#  'Generic 1st Coal, Newcastle  Monthly (ICE)']

# %%
df = pd.read_excel(file_name + ".xlsx")
df
# Out:
#               Unnamed: 0  CL1 Comdty Unnamed: 2  NG1 Comdty Unnamed: 4  \
# 0                    NaN  Last Price     Volume  Last Price     Volume
# 1                  Dates     PX_LAST  PX_VOLUME     PX_LAST  PX_VOLUME
# 2    1983-05-31 00:00:00       30.25       4079         NaN        NaN
# 3    1983-06-30 00:00:00       31.38       4635         NaN        NaN
# 4    1983-07-29 00:00:00          32       4685         NaN        NaN
# ..                   ...         ...        ...         ...        ...
# 490  2024-01-31 00:00:00       75.85    6500574         2.1    3370289
# 491  2024-02-29 00:00:00       78.26    6035887        1.86    3252848
# 492  2024-03-29 00:00:00       83.17    5502850       1.763    2608219
# 493  2024-04-30 00:00:00       81.93    6558260       1.991    3338230
# 494  2024-05-31 00:00:00       76.99    6276478       2.587    3380534
#
#      XW1 Comdty Unnamed: 6
# 0    Last Price     Volume
# 1       PX_LAST  PX_VOLUME
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ..          ...        ...
# 490       116.5        629
# 491         131        355
# 492       129.1        175
# 493      142.25        345
# 494       142.4        148
#
# [495 rows x 7 columns]

# %%
col_names = ["Date"]
for x in names:
    col_names.append(x + ": Price")
    col_names.append(x + ": Vol")
col_names
# Out:
# ['Date',
#  'Generic 1st Crude Oil, WTI (NYM): Price',
#  'Generic 1st Crude Oil, WTI (NYM): Vol',
#  'Generic 1st Natural Gas (NYM): Price',
#  'Generic 1st Natural Gas (NYM): Vol',
#  'Generic 1st Coal, Newcastle  Monthly (ICE): Price',
#  'Generic 1st Coal, Newcastle  Monthly (ICE): Vol']

# %%
df = df.set_axis(col_names, axis = 1)
df
# Out:
#                     Date Generic 1st Crude Oil, WTI (NYM): Price  \
# 0                    NaN                              Last Price
# 1                  Dates                                 PX_LAST
# 2    1983-05-31 00:00:00                                   30.25
# 3    1983-06-30 00:00:00                                   31.38
# 4    1983-07-29 00:00:00                                      32
# ..                   ...                                     ...
# 490  2024-01-31 00:00:00                                   75.85
# 491  2024-02-29 00:00:00                                   78.26
# 492  2024-03-29 00:00:00                                   83.17
# 493  2024-04-30 00:00:00                                   81.93
# 494  2024-05-31 00:00:00                                   76.99
#
#     Generic 1st Crude Oil, WTI (NYM): Vol  \
# 0                                  Volume
# 1                               PX_VOLUME
# 2                                    4079
# 3                                    4635
# 4                                    4685
# ..                                    ...
# 490                               6500574
# 491                               6035887
# 492                               5502850
# 493                               6558260
# 494                               6276478
#
#     Generic 1st Natural Gas (NYM): Price Generic 1st Natural Gas (NYM): Vol  \
# 0                             Last Price                             Volume
# 1                                PX_LAST                          PX_VOLUME
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ..                                   ...                                ...
# 490                                  2.1                            3370289
# 491                                 1.86                            3252848
# 492                                1.763                            2608219
# 493                                1.991                            3338230
# 494                                2.587                            3380534
#
#     Generic 1st Coal, Newcastle  Monthly (ICE): Price  \
# 0                                          Last Price
# 1                                             PX_LAST
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 490                                             116.5
# 491                                               131
# 492                                             129.1
# 493                                            142.25
# 494                                             142.4
#
#     Generic 1st Coal, Newcastle  Monthly (ICE): Vol
# 0                                            Volume
# 1                                         PX_VOLUME
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 490                                             629
# 491                                             355
# 492                                             175
# 493                                             345
# 494                                             148
#
# [495 rows x 7 columns]

# %%
df.to_sql(file_name, engine, if_exists='replace')
# Out:
# 495

# %%
df = pd.read_sql('SELECT * from ' + file_name, con=engine)
df
# Out:
#      index                 Date Generic 1st Crude Oil, WTI (NYM): Price  \
# 0        0                 None                              Last Price
# 1        1                Dates                                 PX_LAST
# 2        2  1983-05-31 00:00:00                                   30.25
# 3        3  1983-06-30 00:00:00                                   31.38
# 4        4  1983-07-29 00:00:00                                      32
# ..     ...                  ...                                     ...
# 490    490  2024-01-31 00:00:00                                   75.85
# 491    491  2024-02-29 00:00:00                                   78.26
# 492    492  2024-03-29 00:00:00                                   83.17
# 493    493  2024-04-30 00:00:00                                   81.93
# 494    494  2024-05-31 00:00:00                                   76.99
#
#     Generic 1st Crude Oil, WTI (NYM): Vol  \
# 0                                  Volume
# 1                               PX_VOLUME
# 2                                    4079
# 3                                    4635
# 4                                    4685
# ..                                    ...
# 490                               6500574
# 491                               6035887
# 492                               5502850
# 493                               6558260
# 494                               6276478
#
#     Generic 1st Natural Gas (NYM): Price Generic 1st Natural Gas (NYM): Vol  \
# 0                             Last Price                             Volume
# 1                                PX_LAST                          PX_VOLUME
# 2                                   None                               None
# 3                                   None                               None
# 4                                   None                               None
# ..                                   ...                                ...
# 490                                  2.1                            3370289
# 491                                 1.86                            3252848
# 492                                1.763                            2608219
# 493                                1.991                            3338230
# 494                                2.587                            3380534
#
#     Generic 1st Coal, Newcastle  Monthly (ICE): Price  \
# 0                                          Last Price
# 1                                             PX_LAST
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 490                                             116.5
# 491                                               131
# 492                                             129.1
# 493                                            142.25
# 494                                             142.4
#
#     Generic 1st Coal, Newcastle  Monthly (ICE): Vol
# 0                                            Volume
# 1                                         PX_VOLUME
# 2                                              None
# 3                                              None
# 4                                              None
# ..                                              ...
# 490                                             629
# 491                                             355
# 492                                             175
# 493                                             345
# 494                                             148
#
# [495 rows x 8 columns]

# %%
connection.close()
