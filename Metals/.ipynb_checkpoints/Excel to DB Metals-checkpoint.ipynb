# %%
import pandas as pd 
from sqlalchemy import create_engine
import mysql.connector

# %%
file_name = "Metals_Prices_data"

host_val = "ubctg.con7266gcvin.us-east-2.rds.amazonaws.com"
user_val = "admin"
password_val = "ubctgquant"
database_val = "ubctg"

# %%
# Connect to MySQL database
connection = mysql.connector.connect(
    host=host_val,
    user=user_val,
    password=password_val,
    database=database_val
)

# %%
hostname= "localhost"
database= "new_db"
username= "username"
password= "password"

engine = create_engine("mysql://{user}:{pw}@{host}/{db}".format(host=host_val, db=database_val, user=user_val, pw=password_val))

# %%
my_file = open("Names.txt", "r") 
names = my_file.read().split("\n") 
my_file.close()

names
# Out:
# ['generic 1st primary aluminum (LME)',
#  'generic 1st copper (LME)',
#  'generic 1st lead (LME)',
#  'generic 1st zinc (LME)',
#  'generic 1st nickel (LME)',
#  'generic 1st tin (LME)',
#  'generic 1st steel billet (LME)',
#  'generic 1st UxC Uranium U308 Swaps (CMX)',
#  'generic 1st silver (CMX)',
#  'generic 1st gold, 100 oz (CMX)',
#  'generic 1st platinum (NYM)',
#  'generic 1st palladium (NYM)']

# %%
df = pd.read_excel(file_name + ".xlsx")
df
# Out:
#               Start Date 1975-01-29 00:00:00 Unnamed: 2  Unnamed: 3  \
# 0               End Date                 NaN        NaN         NaN
# 1                    NaN                 NaN        NaN         NaN
# 2                    NaN          LA1 Comdty        NaN  LP1 Comdty
# 3                    NaN                 NaN        NaN         NaN
# 4                  Dates             PX_LAST  PX_VOLUME     PX_LAST
# ..                   ...                 ...        ...         ...
# 592  2023-12-29 00:00:00              2351.5     765677      8488.5
# 593  2024-01-31 00:00:00             2252.35     697068      8530.5
# 594  2024-02-29 00:00:00             2197.22     612451        8427
# 595  2024-03-29 00:00:00             2306.92     611768     8787.84
# 596  2024-04-30 00:00:00             2565.69     544639     9903.73
#
#     Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0          NaN         NaN        NaN         NaN        NaN         NaN  ...
# 1          NaN         NaN        NaN         NaN        NaN         NaN  ...
# 2          NaN  LL1 Comdty        NaN  LX1 Comdty        NaN  LN1 Comdty  ...
# 3          NaN         NaN        NaN         NaN        NaN         NaN  ...
# 4    PX_VOLUME     PX_LAST  PX_VOLUME     PX_LAST  PX_VOLUME     PX_LAST  ...
# ..         ...         ...        ...         ...        ...         ...  ...
# 592     347837     2044.25      91070        2643     178260       16435  ...
# 593     248683     2176.96     100531     2531.35     147815       16069  ...
# 594     250153        2072     104111     2393.25     183693     17719.5  ...
# 595     269659     2031.92     165206     2403.68     176329    16597.02  ...
# 596     348514     2189.41     109647     2924.82     137191       19102  ...
#
#      Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2    UXA1 Comdty         NaN  SI1 Comdty         NaN  GC1 Comdty         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4        PX_LAST   PX_VOLUME     PX_LAST   PX_VOLUME     PX_LAST   PX_VOLUME
# ..           ...         ...         ...         ...         ...         ...
# 592        91.25           4      24.086       85446      2071.8      243060
# 593       101.25           4      23.169     1222402      2048.4     3866684
# 594        94.45           4      22.666     1243264      2054.7      373245
# 595           88           4      24.916      135191      2217.4     4773623
# 596        89.95           4      26.391     2232484      2302.9      424136
#
#     Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2    PL1 Comdty         NaN  PA1 Comdty         NaN
# 3           NaN         NaN         NaN         NaN
# 4       PX_LAST   PX_VOLUME     PX_LAST   PX_VOLUME
# ..          ...         ...         ...         ...
# 592         995      469170      1109.3        3961
# 593       932.6       42306       996.8       73444
# 594         884      506046       933.5      106138
# 595       907.7      596718      1021.5        6637
# 596       948.2       71060       952.8       92888
#
# [597 rows x 25 columns]

# %%
df = df[2:]
df = df.drop(index = [3,5])
df
# Out:
#               Start Date 1975-01-29 00:00:00 Unnamed: 2  Unnamed: 3  \
# 2                    NaN          LA1 Comdty        NaN  LP1 Comdty
# 4                  Dates             PX_LAST  PX_VOLUME     PX_LAST
# 6    1975-02-28 00:00:00                 NaN        NaN         NaN
# 7    1975-03-31 00:00:00                 NaN        NaN         NaN
# 8    1975-04-30 00:00:00                 NaN        NaN         NaN
# ..                   ...                 ...        ...         ...
# 592  2023-12-29 00:00:00              2351.5     765677      8488.5
# 593  2024-01-31 00:00:00             2252.35     697068      8530.5
# 594  2024-02-29 00:00:00             2197.22     612451        8427
# 595  2024-03-29 00:00:00             2306.92     611768     8787.84
# 596  2024-04-30 00:00:00             2565.69     544639     9903.73
#
#     Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 2          NaN  LL1 Comdty        NaN  LX1 Comdty        NaN  LN1 Comdty  ...
# 4    PX_VOLUME     PX_LAST  PX_VOLUME     PX_LAST  PX_VOLUME     PX_LAST  ...
# 6          NaN         NaN        NaN         NaN        NaN         NaN  ...
# 7          NaN         NaN        NaN         NaN        NaN         NaN  ...
# 8          NaN         NaN        NaN         NaN        NaN         NaN  ...
# ..         ...         ...        ...         ...        ...         ...  ...
# 592     347837     2044.25      91070        2643     178260       16435  ...
# 593     248683     2176.96     100531     2531.35     147815       16069  ...
# 594     250153        2072     104111     2393.25     183693     17719.5  ...
# 595     269659     2031.92     165206     2403.68     176329    16597.02  ...
# 596     348514     2189.41     109647     2924.82     137191       19102  ...
#
#      Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 2    UXA1 Comdty         NaN  SI1 Comdty         NaN  GC1 Comdty         NaN
# 4        PX_LAST   PX_VOLUME     PX_LAST   PX_VOLUME     PX_LAST   PX_VOLUME
# 6            NaN         NaN       4.454         NaN         183         NaN
# 7            NaN         NaN       4.275         NaN       177.1         NaN
# 8            NaN         NaN       4.306         NaN       166.8         NaN
# ..           ...         ...         ...         ...         ...         ...
# 592        91.25           4      24.086       85446      2071.8      243060
# 593       101.25           4      23.169     1222402      2048.4     3866684
# 594        94.45           4      22.666     1243264      2054.7      373245
# 595           88           4      24.916      135191      2217.4     4773623
# 596        89.95           4      26.391     2232484      2302.9      424136
#
#     Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 2    PL1 Comdty         NaN  PA1 Comdty         NaN
# 4       PX_LAST   PX_VOLUME     PX_LAST   PX_VOLUME
# 6           NaN         NaN         NaN         NaN
# 7           NaN         NaN         NaN         NaN
# 8           NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...
# 592         995      469170      1109.3        3961
# 593       932.6       42306       996.8       73444
# 594         884      506046       933.5      106138
# 595       907.7      596718      1021.5        6637
# 596       948.2       71060       952.8       92888
#
# [593 rows x 25 columns]

# %%
col_names = ["Date"]
for x in names:
    col_names.append(x + ": Price")
    col_names.append(x + ": Volume")
col_names
# Out:
# ['Date',
#  'generic 1st primary aluminum (LME): Price',
#  'generic 1st primary aluminum (LME): Volume',
#  'generic 1st copper (LME): Price',
#  'generic 1st copper (LME): Volume',
#  'generic 1st lead (LME): Price',
#  'generic 1st lead (LME): Volume',
#  'generic 1st zinc (LME): Price',
#  'generic 1st zinc (LME): Volume',
#  'generic 1st nickel (LME): Price',
#  'generic 1st nickel (LME): Volume',
#  'generic 1st tin (LME): Price',
#  'generic 1st tin (LME): Volume',
#  'generic 1st steel billet (LME): Price',
#  'generic 1st steel billet (LME): Volume',
#  'generic 1st UxC Uranium U308 Swaps (CMX): Price',
#  'generic 1st UxC Uranium U308 Swaps (CMX): Volume',
#  'generic 1st silver (CMX): Price',
#  'generic 1st silver (CMX): Volume',
#  'generic 1st gold, 100 oz (CMX): Price',
#  'generic 1st gold, 100 oz (CMX): Volume',
#  'generic 1st platinum (NYM): Price',
#  'generic 1st platinum (NYM): Volume',
#  'generic 1st palladium (NYM): Price',
#  'generic 1st palladium (NYM): Volume']

# %%
df = df.set_axis(col_names, axis = 1)
df
# Out:
#                     Date generic 1st primary aluminum (LME): Price  \
# 2                    NaN                                LA1 Comdty
# 4                  Dates                                   PX_LAST
# 6    1975-02-28 00:00:00                                       NaN
# 7    1975-03-31 00:00:00                                       NaN
# 8    1975-04-30 00:00:00                                       NaN
# ..                   ...                                       ...
# 592  2023-12-29 00:00:00                                    2351.5
# 593  2024-01-31 00:00:00                                   2252.35
# 594  2024-02-29 00:00:00                                   2197.22
# 595  2024-03-29 00:00:00                                   2306.92
# 596  2024-04-30 00:00:00                                   2565.69
#
#     generic 1st primary aluminum (LME): Volume  \
# 2                                          NaN
# 4                                    PX_VOLUME
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# ..                                         ...
# 592                                     765677
# 593                                     697068
# 594                                     612451
# 595                                     611768
# 596                                     544639
#
#     generic 1st copper (LME): Price generic 1st copper (LME): Volume  \
# 2                        LP1 Comdty                              NaN
# 4                           PX_LAST                        PX_VOLUME
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8                               NaN                              NaN
# ..                              ...                              ...
# 592                          8488.5                           347837
# 593                          8530.5                           248683
# 594                            8427                           250153
# 595                         8787.84                           269659
# 596                         9903.73                           348514
#
#     generic 1st lead (LME): Price generic 1st lead (LME): Volume  \
# 2                      LL1 Comdty                            NaN
# 4                         PX_LAST                      PX_VOLUME
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# ..                            ...                            ...
# 592                       2044.25                          91070
# 593                       2176.96                         100531
# 594                          2072                         104111
# 595                       2031.92                         165206
# 596                       2189.41                         109647
#
#     generic 1st zinc (LME): Price generic 1st zinc (LME): Volume  \
# 2                      LX1 Comdty                            NaN
# 4                         PX_LAST                      PX_VOLUME
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# ..                            ...                            ...
# 592                          2643                         178260
# 593                       2531.35                         147815
# 594                       2393.25                         183693
# 595                       2403.68                         176329
# 596                       2924.82                         137191
#
#     generic 1st nickel (LME): Price  ...  \
# 2                        LN1 Comdty  ...
# 4                           PX_LAST  ...
# 6                               NaN  ...
# 7                               NaN  ...
# 8                               NaN  ...
# ..                              ...  ...
# 592                           16435  ...
# 593                           16069  ...
# 594                         17719.5  ...
# 595                        16597.02  ...
# 596                           19102  ...
#
#     generic 1st UxC Uranium U308 Swaps (CMX): Price  \
# 2                                       UXA1 Comdty
# 4                                           PX_LAST
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# ..                                              ...
# 592                                           91.25
# 593                                          101.25
# 594                                           94.45
# 595                                              88
# 596                                           89.95
#
#     generic 1st UxC Uranium U308 Swaps (CMX): Volume  \
# 2                                                NaN
# 4                                          PX_VOLUME
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# ..                                               ...
# 592                                                4
# 593                                                4
# 594                                                4
# 595                                                4
# 596                                                4
#
#     generic 1st silver (CMX): Price generic 1st silver (CMX): Volume  \
# 2                        SI1 Comdty                              NaN
# 4                           PX_LAST                        PX_VOLUME
# 6                             4.454                              NaN
# 7                             4.275                              NaN
# 8                             4.306                              NaN
# ..                              ...                              ...
# 592                          24.086                            85446
# 593                          23.169                          1222402
# 594                          22.666                          1243264
# 595                          24.916                           135191
# 596                          26.391                          2232484
#
#     generic 1st gold, 100 oz (CMX): Price  \
# 2                              GC1 Comdty
# 4                                 PX_LAST
# 6                                     183
# 7                                   177.1
# 8                                   166.8
# ..                                    ...
# 592                                2071.8
# 593                                2048.4
# 594                                2054.7
# 595                                2217.4
# 596                                2302.9
#
#     generic 1st gold, 100 oz (CMX): Volume generic 1st platinum (NYM): Price  \
# 2                                      NaN                        PL1 Comdty
# 4                                PX_VOLUME                           PX_LAST
# 6                                      NaN                               NaN
# 7                                      NaN                               NaN
# 8                                      NaN                               NaN
# ..                                     ...                               ...
# 592                                 243060                               995
# 593                                3866684                             932.6
# 594                                 373245                               884
# 595                                4773623                             907.7
# 596                                 424136                             948.2
#
#     generic 1st platinum (NYM): Volume generic 1st palladium (NYM): Price  \
# 2                                  NaN                         PA1 Comdty
# 4                            PX_VOLUME                            PX_LAST
# 6                                  NaN                                NaN
# 7                                  NaN                                NaN
# 8                                  NaN                                NaN
# ..                                 ...                                ...
# 592                             469170                             1109.3
# 593                              42306                              996.8
# 594                             506046                              933.5
# 595                             596718                             1021.5
# 596                              71060                              952.8
#
#     generic 1st palladium (NYM): Volume
# 2                                   NaN
# 4                             PX_VOLUME
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# ..                                  ...
# 592                                3961
# 593                               73444
# 594                              106138
# 595                                6637
# 596                               92888
#
# [593 rows x 25 columns]

# %%
df = df.reset_index()
df = df.drop('index', axis = 1)
df
# Out:
#                     Date generic 1st primary aluminum (LME): Price  \
# 0                    NaN                                LA1 Comdty
# 1                  Dates                                   PX_LAST
# 2    1975-02-28 00:00:00                                       NaN
# 3    1975-03-31 00:00:00                                       NaN
# 4    1975-04-30 00:00:00                                       NaN
# ..                   ...                                       ...
# 588  2023-12-29 00:00:00                                    2351.5
# 589  2024-01-31 00:00:00                                   2252.35
# 590  2024-02-29 00:00:00                                   2197.22
# 591  2024-03-29 00:00:00                                   2306.92
# 592  2024-04-30 00:00:00                                   2565.69
#
#     generic 1st primary aluminum (LME): Volume  \
# 0                                          NaN
# 1                                    PX_VOLUME
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 588                                     765677
# 589                                     697068
# 590                                     612451
# 591                                     611768
# 592                                     544639
#
#     generic 1st copper (LME): Price generic 1st copper (LME): Volume  \
# 0                        LP1 Comdty                              NaN
# 1                           PX_LAST                        PX_VOLUME
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# ..                              ...                              ...
# 588                          8488.5                           347837
# 589                          8530.5                           248683
# 590                            8427                           250153
# 591                         8787.84                           269659
# 592                         9903.73                           348514
#
#     generic 1st lead (LME): Price generic 1st lead (LME): Volume  \
# 0                      LL1 Comdty                            NaN
# 1                         PX_LAST                      PX_VOLUME
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# ..                            ...                            ...
# 588                       2044.25                          91070
# 589                       2176.96                         100531
# 590                          2072                         104111
# 591                       2031.92                         165206
# 592                       2189.41                         109647
#
#     generic 1st zinc (LME): Price generic 1st zinc (LME): Volume  \
# 0                      LX1 Comdty                            NaN
# 1                         PX_LAST                      PX_VOLUME
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# ..                            ...                            ...
# 588                          2643                         178260
# 589                       2531.35                         147815
# 590                       2393.25                         183693
# 591                       2403.68                         176329
# 592                       2924.82                         137191
#
#     generic 1st nickel (LME): Price  ...  \
# 0                        LN1 Comdty  ...
# 1                           PX_LAST  ...
# 2                               NaN  ...
# 3                               NaN  ...
# 4                               NaN  ...
# ..                              ...  ...
# 588                           16435  ...
# 589                           16069  ...
# 590                         17719.5  ...
# 591                        16597.02  ...
# 592                           19102  ...
#
#     generic 1st UxC Uranium U308 Swaps (CMX): Price  \
# 0                                       UXA1 Comdty
# 1                                           PX_LAST
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 588                                           91.25
# 589                                          101.25
# 590                                           94.45
# 591                                              88
# 592                                           89.95
#
#     generic 1st UxC Uranium U308 Swaps (CMX): Volume  \
# 0                                                NaN
# 1                                          PX_VOLUME
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 588                                                4
# 589                                                4
# 590                                                4
# 591                                                4
# 592                                                4
#
#     generic 1st silver (CMX): Price generic 1st silver (CMX): Volume  \
# 0                        SI1 Comdty                              NaN
# 1                           PX_LAST                        PX_VOLUME
# 2                             4.454                              NaN
# 3                             4.275                              NaN
# 4                             4.306                              NaN
# ..                              ...                              ...
# 588                          24.086                            85446
# 589                          23.169                          1222402
# 590                          22.666                          1243264
# 591                          24.916                           135191
# 592                          26.391                          2232484
#
#     generic 1st gold, 100 oz (CMX): Price  \
# 0                              GC1 Comdty
# 1                                 PX_LAST
# 2                                     183
# 3                                   177.1
# 4                                   166.8
# ..                                    ...
# 588                                2071.8
# 589                                2048.4
# 590                                2054.7
# 591                                2217.4
# 592                                2302.9
#
#     generic 1st gold, 100 oz (CMX): Volume generic 1st platinum (NYM): Price  \
# 0                                      NaN                        PL1 Comdty
# 1                                PX_VOLUME                           PX_LAST
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
# ..                                     ...                               ...
# 588                                 243060                               995
# 589                                3866684                             932.6
# 590                                 373245                               884
# 591                                4773623                             907.7
# 592                                 424136                             948.2
#
#     generic 1st platinum (NYM): Volume generic 1st palladium (NYM): Price  \
# 0                                  NaN                         PA1 Comdty
# 1                            PX_VOLUME                            PX_LAST
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 588                             469170                             1109.3
# 589                              42306                              996.8
# 590                             506046                              933.5
# 591                             596718                             1021.5
# 592                              71060                              952.8
#
#     generic 1st palladium (NYM): Volume
# 0                                   NaN
# 1                             PX_VOLUME
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 588                                3961
# 589                               73444
# 590                              106138
# 591                                6637
# 592                               92888
#
# [593 rows x 25 columns]

# %%
df.iloc[0] = df.iloc[0].fillna(method = 'ffill')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df[0] = df[0].fillna(method = 'ffill')
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
df.to_sql(file_name, engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# DuplicateColumnError                      Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df.to_sql(file_name, engine, if_exists='replace')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3084, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
#    3080 [(1,), (None,), (2,)]
#    3081 """  # noqa: E501
#    3082 from pandas.io import sql
# -> 3084 return sql.to_sql(
#    3085     self,
#    3086     name,
#    3087     con,
#    3088     schema=schema,
#    3089     if_exists=if_exists,
#    3090     index=index,
#    3091     index_label=index_label,
#    3092     chunksize=chunksize,
#    3093     dtype=dtype,
#    3094     method=method,
#    3095 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2008, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1958 """
#    1959 Write records stored in a DataFrame to a SQL database.
#    1960
#    (...)
#    2004     Any additional kwargs are passed to the engine.
#    2005 """
#    2006 sql_engine = get_engine(engine)
# -> 2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    2011     if_exists=if_exists,
#    2012     index=index,
#    2013     index_label=index_label,
#    2014     schema=schema,
#    2015     dtype=dtype,
#    2016 )
#    2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    (...)
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1902, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1899         else:
#    1900             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
# -> 1902 table = SQLTable(
#    1903     name,
#    1904     self,
#    1905     frame=frame,
#    1906     index=index,
#    1907     if_exists=if_exists,
#    1908     index_label=index_label,
#    1909     schema=schema,
#    1910     dtype=dtype,
#    1911 )
#    1912 table.create()
#    1913 return table
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:958, in SQLTable.__init__(self, name, pandas_sql_engine, frame, index, if_exists, prefix, index_label, schema, keys, dtype)
#     954 self.dtype = dtype
#     956 if frame is not None:
#     957     # We want to initialize based on a dataframe
# --> 958     self.table = self._create_table_setup()
#     959 else:
#     960     # no data provided, read-only mode
#     961     self.table = self.pd_sql.get_table(self.name, self.schema)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1285, in SQLTable._create_table_setup(self)
#    1282 # At this point, attach to new metadata, only attach to self.meta
#    1283 # once table is created.
#    1284 meta = MetaData()
# -> 1285 return Table(self.name, meta, *columns, schema=schema)
#
# File <string>:2, in __new__(cls, *args, **kw)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:436, in Table.__new__(cls, *args, **kw)
#     429 @util.deprecated_params(
#     430     mustexist=(
#     431         "1.4",
#    (...)
#     434 )
#     435 def __new__(cls, *args: Any, **kw: Any) -> Any:
# --> 436     return cls._new(*args, **kw)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:490, in Table._new(cls, *args, **kw)
#     488     return table
#     489 except Exception:
# --> 490     with util.safe_reraise():
#     491         metadata._remove_table(name, schema)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:486, in Table._new(cls, *args, **kw)
#     484 metadata._add_table(name, schema, table)
#     485 try:
# --> 486     table.__init__(name, metadata, *args, _no_init=False, **kw)
#     487     table.dispatch.after_parent_attach(table, metadata)
#     488     return table
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:878, in Table.__init__(self, name, metadata, schema, quote, quote_schema, autoload_with, autoload_replace, keep_existing, extend_existing, resolve_fks, include_columns, implicit_returning, comment, info, listeners, prefixes, _extend_on, _no_init, *args, **kw)
#     866     self._autoload(
#     867         metadata,
#     868         autoload_with,
#    (...)
#     872         resolve_fks=resolve_fks,
#     873     )
#     875 # initialize all the column, etc. objects.  done after reflection to
#     876 # allow user-overrides
# --> 878 self._init_items(
#     879     *args,
#     880     allow_replacements=extend_existing
#     881     or keep_existing
#     882     or autoload_with,
#     883     all_names={},
#     884 )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:231, in SchemaItem._init_items(self, *args, **kw)
#     226     raise exc.ArgumentError(
#     227         "'SchemaItem' object, such as a 'Column' or a "
#     228         f"'Constraint' expected, got {item!r}"
#     229     ) from err
#     230 else:
# --> 231     spwd(self, **kw)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\base.py:1337, in SchemaEventTarget._set_parent_with_dispatch(self, parent, **kw)
#    1333 def _set_parent_with_dispatch(
#    1334     self, parent: SchemaEventTarget, **kw: Any
#    1335 ) -> None:
#    1336     self.dispatch.before_parent_attach(self, parent)
# -> 1337     self._set_parent(parent, **kw)
#    1338     self.dispatch.after_parent_attach(self, parent)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:2342, in Column._set_parent(self, parent, all_names, allow_replacements, **kw)
#    2340 if existing_col is not self:
#    2341     if not allow_replacements:
# -> 2342         raise exc.DuplicateColumnError(
#    2343             f"A column with {conflicts_on} "
#    2344             f"""'{
#    2345                 self.key if conflicts_on == 'key' else self.name
#    2346             }' """
#    2347             f"is already present in table '{table.name}'."
#    2348         )
#    2349     for fk in existing_col.foreign_keys:
#    2350         table.foreign_keys.remove(fk)
#
# DuplicateColumnError: A column with name 'generic 1st primary aluminum (LME)' is already present in table 'Metals_Prices_data'.

# %%
df = pd.read_sql('SELECT * from ' + file_name, con=engine)
df

# %%
connection.close()
